# %%
from fastbook import *

# %%
urls = search_images_ddg("bird photos", max_images=100)
urls
# Out:
# (#100) ['https://media-manager.starsinsider.com/gallery/1920/na_5dee1742c9d0a.jpg','https://a-z-animals.com/media/2022/06/Lovebirds-on-fence.jpg','http://2.bp.blogspot.com/-TQ1S9XhEEp8/Un6hh6fGCqI/AAAAAAAAWPg/hEx0QsLVIEk/s1600/1600x1200-beautiful-bird-sitting-on-branch-hd-bird-wallpaper-animal.jpg','http://hdqwalls.com/download/1/colorful-parrot-bird.jpg','https://www.almanac.com/sites/default/files/image_nodes/bluebird-3456115_1920.jpg','https://jooinn.com/images/cardinal-20.jpg','https://wallpapercave.com/wp/9HgpMb0.jpg','https://images.pexels.com/photos/326900/pexels-photo-326900.jpeg?cs=srgb&dl=wood-flight-bird-326900.jpg&fm=jpg','https://i.pinimg.com/originals/16/c2/a0/16c2a0598565ee269f07a9857c227ec1.jpg','http://www.birdwatchingincostarica.com/wp-content/uploads/2015/10/Blue-Crowned-Motmot-copia.jpg'...]

# %%
dest = Path("bird.jpg")
if not dest.exists():
    download_url(urls[0], dest, show_progress=False)

# %% [markdown]
# > [PixSpy](https://pixspy.com/) 可以查看圖片每個像素點的資訊

# %%
img = Image.open(dest)
img.thumbnail((256, 256))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x213>
